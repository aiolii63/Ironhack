# %% [markdown]
# # Subsetting and Descriptive Stats
#
# ## Before your start:
#    - Remember that you just need to do one of the challenges.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in IronHack's database.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly: enjoy the process!
#
# #### Import all the necessary libraries here:

# %%
# import libraries here

import numpy as np
import pandas as pd

# %% [markdown]
# # Challenge 1
# #### In this challenge we will use the `Temp_States`  dataset.
#
# #### First import it into a dataframe called `temp`.

# %%
# your code here

temp = pd.read_csv('C:/Users/olivi/Documents/Ironhack/DAFT_212/module_2/Lab_10_Subsetting-and-Descriptive-Statistics/Temp_States.csv')
temp.head()
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444

# %% [markdown]
# #### Print `temp`.

# %%
# your code here
print(temp)
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the *temp* dataframe. What types of data do we have? Comment your result.

# %%
# your code here

temp.dtypes
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %%
"""
your comments here: only one field is numeric. The other two are categorical...
"""

# %% [markdown]
# #### Select the rows where state is New York.

# %%
# your code here

temp[temp['State']=="New York"]
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average temperature of cities in New York?

# %%
# your code here

temp[temp['State']=="New York"]["Temperature"].mean()
# Out:
# 10.74074074074074

# %% [markdown]
# #### Which states and cities have a temperature above 15 degrees Celsius?

# %%
# your code here

temp[temp['Temperature']>15]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degrees Celsius.

# %%
# your code here

temp[temp['Temperature']>15]['City']
# Out:
# 0         NYC
# 3    Hartford
# 5      Treton
# 6      Newark
# Name: City, dtype: object

# %% [markdown]
# #### Which cities have a temperature above 15 degrees Celcius and below 20 degrees Celsius?
#
# **Hint**: First, write the condition. Then, select the rows.

# %%
# your code here

temp[["City","Temperature"]].loc[(temp['Temperature'] > 15) & (temp['Temperature'] < 20)]
# Out:
#        City  Temperature
# 0       NYC    19.444444
# 3  Hartford    17.222222

# %% [markdown]
# #### Find the mean and standard deviation of the temperature of each state.

# %%
# your code here

temp["Temperature"].groupby(temp["State"]).mean()
# Out:
# State
# Connecticut    15.833333
# New Jersey     21.111111
# New York       10.740741
# Name: Temperature, dtype: float64

# %%
temp["Temperature"].groupby(temp["State"]).std()
# Out:
# State
# Connecticut    1.964186
# New Jersey     1.571348
# New York       8.133404
# Name: Temperature, dtype: float64

# %% [markdown]
# #  Challenge 2

# %% [markdown]
# #### Load the `employees` dataset into a dataframe. Call the dataframe `employees`.

# %%
# your code here

employees = pd.read_csv('C:/Users/olivi/Documents/Ironhack/DAFT_212/module_2/Lab_10_Subsetting-and-Descriptive-Statistics/employees.csv')
employees.head()
# Out:
#   Department Education      Title      Name  Years  Salary
# 0      Admin    Master  associate     David      4      58
# 1         IT    Master  associate    Thomas      7      45
# 2      Admin    Master  associate     Diana     10      52
# 3      Admin    Master         VP  Manuella     15      33
# 4      Sales    Master    Analyst     Carla      6      38

# %% [markdown]
# #### Explore the data types of the `employees` dataframe. Comment your results.

# %%
# your code here
employees.dtypes
# Out:
# Department    object
# Education     object
# Title         object
# Name          object
# Years          int64
# Salary         int64
# dtype: object

# %%
employees.describe()
# Out:
#             Years      Salary
# count  500.000000  500.000000
# mean     7.556000   73.528000
# std      4.465731   26.890061
# min      1.000000   30.000000
# 25%      3.000000   50.000000
# 50%      7.000000   72.000000
# 75%     11.250000   97.000000
# max     15.000000  120.000000

# %%
"""
your comments here: 2 numerical variables (years, salary) and 4 categorical variables...
"""

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your code here

employees['Salary'].mean()
# Out:
# 73.528

# %% [markdown]
# #### What's the highest salary?

# %%
# your code here
employees['Salary'].max()
# Out:
# 120

# %% [markdown]
# #### What's the lowest salary?

# %%
# your code here
employees['Salary'].min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your code here

employees[employees["Salary"]== np.min(employees["Salary"])]
# Out:
#     Department Education      Title      Name  Years  Salary
# 27          IT  Bachelor    Analyst      Sean     12      30
# 106      Admin  Bachelor  associate      Luke      4      30
# 128      Sales       PhD         VP      Adam      8      30
# 139      Sales       PhD    Analyst      Rick     11      30
# 214      Sales    Master         VP      Neil     11      30
# 266         HR       PhD  associate    Marcel     10      30
# 452         IT  Bachelor    Analyst  Augustin     13      30

# %% [markdown]
# #### Find all the information about an employee called David.

# %%
# your code here

employees[employees["Name"]== "David"]
# Out:
#     Department Education      Title   Name  Years  Salary
# 0        Admin    Master  associate  David      4      58
# 124         IT  Bachelor         VP  David      3      31

# %% [markdown]
# #### Could you return only David's salary?

# %%
# your code here

#We have 2 Davids: one at IT, another at Admin

# %% [markdown]
# #### Print all the rows where job title is associate.

# %%
# your code here

employees[employees["Title"]=="associate"]
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 1           IT    Master  associate    Thomas      7      45
# 2        Admin    Master  associate     Diana     10      52
# 7           HR    Master  associate     Carol     14      53
# 8        Admin       PhD  associate      Jean      8      50
# ..         ...       ...        ...       ...    ...     ...
# 477         HR       PhD  associate   Phillip     11     113
# 486         IT  Bachelor  associate       Jay     14      58
# 487         HR    Master  associate  Patricia     10     110
# 491      Admin       PhD  associate     Alice      8      37
# 494      Sales  Bachelor  associate   Vanessa     11     118
#
# [158 rows x 6 columns]

# %% [markdown]
# #### Print the first 3 rows of your dataframe.
# **Tip**: There are 2 ways to do it. Do it both ways.

# %%
# Method 1
# your code here

employees.head(3)
# Out:
#   Department Education      Title    Name  Years  Salary
# 0      Admin    Master  associate   David      4      58
# 1         IT    Master  associate  Thomas      7      45
# 2      Admin    Master  associate   Diana     10      52

# %%
# Method 2
# your code here

employees[:3]
# Out:
#   Department Education      Title    Name  Years  Salary
# 0      Admin    Master  associate   David      4      58
# 1         IT    Master  associate  Thomas      7      45
# 2      Admin    Master  associate   Diana     10      52

# %% [markdown]
# #### Find the employees whose title is associate and whose salary is above 55.

# %%
# your code here

employees.loc[(employees["Title"]=="associate") & (employees["Salary"]>55)]
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 9        Admin    Master  associate    Kareem      3     104
# 10       Admin    Master  associate   Cynthia      1     114
# 16       Admin  Bachelor  associate    Shanon      1      99
# 18       Admin  Bachelor  associate     Megan      9      79
# ..         ...       ...        ...       ...    ...     ...
# 476      Admin       PhD  associate      Greg      8      93
# 477         HR       PhD  associate   Phillip     11     113
# 486         IT  Bachelor  associate       Jay     14      58
# 487         HR    Master  associate  Patricia     10     110
# 494      Sales  Bachelor  associate   Vanessa     11     118
#
# [104 rows x 6 columns]

# %% [markdown]
# #### Group the employees by number of years of employment. What are the average salaries in each group?

# %%
# your code here

employees.groupby(["Years"])["Salary"].mean()
# Out:
# Years
# 1     75.863636
# 2     75.857143
# 3     74.571429
# 4     77.129032
# 5     73.857143
# 6     72.382353
# 7     73.840000
# 8     64.250000
# 9     76.741935
# 10    73.351351
# 11    74.866667
# 12    73.454545
# 13    71.935484
# 14    70.968750
# 15    69.758621
# Name: Salary, dtype: float64

# %% [markdown]
# ####  What is the average salary per title?

# %%
# your code here

employees.groupby(["Title"])["Salary"].mean()
# Out:
# Title
# Analyst      73.703911
# VP           72.907975
# associate    73.968354
# Name: Salary, dtype: float64

# %% [markdown]
# ####  Find the salary quartiles.

# %%
# your code here

employees["Salary"].describe()
# Out:
# count    500.000000
# mean      73.528000
# std       26.890061
# min       30.000000
# 25%       50.000000
# 50%       72.000000
# 75%       97.000000
# max      120.000000
# Name: Salary, dtype: float64

# %% [markdown]
# #### Is the mean salary different per gender?

# %%
employees["Name"].value_counts()
# Out:
# Kareem     9
# Chad       6
# Edgar      6
# Phillip    6
# Jean       6
#           ..
# Denise     1
# Craig      1
# Joyce      1
# Lance      1
# Cal        1
# Name: Name, Length: 201, dtype: int64

# %% [markdown]
# #### Find the minimum, mean and maximum of all numeric columns for each company department.

# %%
# your code here

employees.groupby("Department")[["Years","Salary"]].mean()
# Out:
#                Years     Salary
# Department
# Admin       7.642276  76.325203
# HR          7.172131  74.237705
# IT          8.141791  70.671642
# Sales       7.206612  73.132231

# %%
employees.groupby("Department")[["Years","Salary"]].min()
# Out:
#             Years  Salary
# Department
# Admin           1      30
# HR              1      30
# IT              1      30
# Sales           1      30

# %%
employees.groupby("Department")[["Years","Salary"]].max()
# Out:
#             Years  Salary
# Department
# Admin          15     120
# HR             15     119
# IT             15     120
# Sales          15     120

# %% [markdown]
# #### Bonus Question:  for each department, compute the difference between the maximum and the minimum salary.
# **Hint**: try using `agg` or `apply` combined with `lambda` functions.

# %%
# your code here

# %% [markdown]
# # Challenge 3
# #### Open the `Orders` dataset. Name your dataset `orders`.

# %%
# your code here

orders = pd.read_csv('C:/Users/olivi/Documents/Ironhack/DAFT_212/module_2/Lab_10_Subsetting-and-Descriptive-Statistics/Orders.csv')
orders.head()
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
#
#                            Description  Quantity         InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 8:26:00
# 1                  white metal lantern         6  2010-12-01 8:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 8:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 8:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 8:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# ...

# %% [markdown]
# #### Explore your dataset by looking at the data types and summary statistics. Comment your results.

# %%
# your code here

orders.dtypes
# Out:
# Unnamed: 0        int64
# InvoiceNo         int64
# StockCode        object
# year              int64
# month             int64
# day               int64
# hour              int64
# Description      object
# Quantity          int64
# InvoiceDate      object
# UnitPrice       float64
# CustomerID        int64
# Country          object
# amount_spent    float64
# dtype: object

# %%
orders.describe().round(1)
# Out:
#        Unnamed: 0  InvoiceNo      year     month       day      hour  \
# count    397924.0   397924.0  397924.0  397924.0  397924.0  397924.0
# mean     278465.2   560617.1    2010.9       7.6       3.6      12.7
# std      152771.4    13106.2       0.2       3.4       1.9       2.3
# min           0.0   536365.0    2010.0       1.0       1.0       6.0
# 25%      148333.8   549234.0    2011.0       5.0       2.0      11.0
# 50%      284907.5   561893.0    2011.0       8.0       3.0      13.0
# 75%      410079.2   572090.0    2011.0      11.0       5.0      14.0
# max      541908.0   581587.0    2011.0      12.0       7.0      20.0
#
#        Quantity  UnitPrice  CustomerID  amount_spent
# count  397924.0   397924.0    397924.0      397924.0
# mean       13.0        3.1     15294.3          22.4
# std       180.4       22.1      1713.2         309.1
# min         1.0        0.0     12346.0           0.0
# 25%         2.0        1.2     13969.0           4.7
# ...

# %%
"""
your comments here: 
Unnamed:0 could be dropped from the table
Invoice No shouldnt be considered as a numeric field: it should be a categorical field instead
Year, Month and Date should be date types instead of numeric
CustomerID should be a categorical field (not numeric) 

"""

# %%
orders.drop(columns="Unnamed: 0")
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 0          536365    85123A  2010     12    3     8
# 1          536365     71053  2010     12    3     8
# 2          536365    84406B  2010     12    3     8
# 3          536365    84029G  2010     12    3     8
# 4          536365    84029E  2010     12    3     8
# ...           ...       ...   ...    ...  ...   ...
# 397919     581587     22613  2011     12    5    12
# 397920     581587     22899  2011     12    5    12
# 397921     581587     23254  2011     12    5    12
# 397922     581587     23255  2011     12    5    12
# 397923     581587     22138  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 0        white hanging heart t-light holder         6   2010-12-01 8:26:00
# 1                       white metal lantern         6   2010-12-01 8:26:00
# 2            cream cupid hearts coat hanger         8   2010-12-01 8:26:00
# ...

# %% [markdown]
# ####  What is the average purchase price?

# %%
# your code here

orders['amount_spent'].mean()
# Out:
# 22.394748504739596

# %% [markdown]
# #### What are the highest and lowest purchase prices?

# %%
# your code here

orders['amount_spent'].max()
# Out:
# 168469.6

# %%
orders['amount_spent'].min()
# Out:
# 0.0

# %% [markdown]
# #### Select all the customers from Spain.
# **Hint**: Remember that you are not asked to find orders from Spain but customers. A customer might have more than one order associated.

# %%
# your code here

orders[orders['Country']=="Spain"]["CustomerID"]
# Out:
# 4250      12557
# 4251      12557
# 4252      12557
# 4253      12557
# 4254      12557
#           ...
# 394733    17097
# 394734    17097
# 394735    17097
# 394736    17097
# 394737    17097
# Name: CustomerID, Length: 2485, dtype: int64

# %% [markdown]
# #### How many customers do we have in Spain?

# %%
# your code here

spain = orders[orders['Country']=="Spain"]["CustomerID"].unique()
print(len(spain))
# Out:
# 30

# %% [markdown]
# #### Select all the customers who have bought more than 50 items.
# **Hint**: Remember that you are not asked to find orders with more than 50 items but customers who bought more than 50 items. A customer with two orders of 30 items each should appear in the selection.

# %%
# your code here

qty = orders.groupby('CustomerID')['Quantity'].sum().reset_index()
qty.sort_values('Quantity', ascending=False)

final = qty[qty['Quantity']>=50].sort_values('Quantity', ascending=False)
final
# Out:
#       CustomerID  Quantity
# 1690       14646    197491
# 3009       16446     80997
# 1880       14911     80515
# 55         12415     77670
# 0          12346     74215
# ...          ...       ...
# 641        13193        50
# 3491       17110        50
# 2641       15944        50
# 4074       17923        50
# 4255       18174        50
#
# [4098 rows x 2 columns]

# %% [markdown]
# #### Select orders from Spain that include more than 50 items.

# %%
# your code here

orders[(orders['Country']=="Spain") & (orders['Quantity']>50)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# 32454        52416     540785    84997B  2011      1    2    11
# 32455        52417     540785    84997D  2011      1    2    11
# 32456        52418     540785    84997C  2011      1    2    11
# 32457        52419     540785    84997A  2011      1    2    11
# 91155       136767     547972     22383  2011      3    1    16
# 91156       136768     547972     22384  2011      3    1    16
# 91159       136771     547972     20728  2011      3    1    16
# 174442      248797     558871     22384  2011      7    1    13
# 174443      248798     558871     20727  2011      7    1    13
# ...

# %% [markdown]
# #### Select all free orders.

# %%
# your code here

orders[orders['amount_spent']==0]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Select all orders whose description starts with `lunch bag`.
# **Hint**: use string functions.

# %%
# your code here

orders[orders['Description'].str.startswith("lunch bag")]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93              93     536378     20725  2010     12    3     9
# 172            174     536385     22662  2010     12    3     9
# 354            363     536401     22662  2010     12    3    11
# 359            368     536401     20725  2010     12    3    11
# 360            369     536401     22382  2010     12    3    11
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot        10   2010-12-01 9:37:00       1.65
# ...

# %% [markdown]
# #### Select all `lunch bag` orders made in 2011.

# %%
# your code here
orders[(orders['Description'].str.contains('lunch bag')) & (orders['year']==2011)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26340        42678     540015     20725  2011      1    2    11
# 26341        42679     540015     20726  2011      1    2    11
# 26512        42851     540023     22382  2011      1    2    12
# 26513        42852     540023     20726  2011      1    2    12
# 26860        43616     540098     22384  2011      1    2    15
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 26340       lunch bag red retrospot        10  2011-01-04 11:40:00       1.65
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your code here

orders[orders['Country']=="Spain"]['amount_spent'].value_counts()
# Out:
# 15.00     186
# 17.70     122
# 19.80      99
# 17.40      86
# 10.20      76
#          ...
# 2.60        1
# 5.85        1
# 27.00       1
# 41.60       1
# 109.50      1
# Name: amount_spent, Length: 309, dtype: int64

# %% [markdown]
# #### Select all orders made in the month of August.

# %%
# your code here

orders[orders['month']==8]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 226483      320688     565067     22644  2011      8    3    17
# 226484      320689     565067     22645  2011      8    3    17
# 226485      320690     565067     22637  2011      8    3    17
# 226486      320691     565067     22646  2011      8    3    17
# 226487      320692     565067     22741  2011      8    3    17
#
#                                 Description  Quantity          InvoiceDate  \
# 199475          6 ribbons elegant christmas        96   2011-08-01 8:30:00
# ...

# %% [markdown]
# #### Find the number of orders made by each country in the month of August.
# **Hint**: Use value_counts().

# %%
# your code here

ordersperctry= orders[orders['month']==8].groupby('Country')['InvoiceNo'].count().reset_index()
ordersperctry
# Out:
#             Country  InvoiceNo
# 0         Australia        107
# 1           Austria         88
# 2           Belgium        194
# 3            Canada          5
# 4   Channel Islands        140
# 5           Denmark         16
# 6              EIRE        593
# 7           Finland         61
# 8            France        569
# 9           Germany        795
# 10          Iceland         22
# 11           Israel        171
# 12            Italy         95
# 13            Malta         55
# 14      Netherlands        280
# 15           Norway         77
# 16           Poland         17
# 17         Portugal         41
# 18            Spain        252
# 19           Sweden         40
# 20      Switzerland        267
# 21   United Kingdom      23105
# 22      Unspecified         23

# %%
ordersperctry.sort_values('InvoiceNo', ascending=False)
# Out:
#             Country  InvoiceNo
# 21   United Kingdom      23105
# 9           Germany        795
# 6              EIRE        593
# 8            France        569
# 14      Netherlands        280
# 20      Switzerland        267
# 18            Spain        252
# 2           Belgium        194
# 11           Israel        171
# 4   Channel Islands        140
# 0         Australia        107
# 12            Italy         95
# 1           Austria         88
# 15           Norway         77
# 7           Finland         61
# 13            Malta         55
# 17         Portugal         41
# 19           Sweden         40
# 22      Unspecified         23
# 10          Iceland         22
# 16           Poland         17
# 5           Denmark         16
# 3            Canada          5

# %% [markdown]
# #### What's the  average amount of money spent by country?

# %%
# your code here

orders.groupby('Country')['amount_spent'].mean().sort_values(ascending=False)
# Out:
# Country
# Netherlands             120.798282
# Australia               116.895620
# Japan                   116.561900
# Singapore                95.852658
# Sweden                   85.096075
# Denmark                  49.882474
# Lithuania                47.458857
# Lebanon                  37.641778
# EIRE                     36.687745
# Brazil                   35.737500
# Norway                   33.736418
# Czech Republic           33.069600
# Finland                  32.913985
# Greece                   32.831172
# Bahrain                  32.258824
# Switzerland              30.642752
# Israel                   29.119718
# United Arab Emirates     27.974706
# Channel Islands          27.340160
# Austria                  25.624824
# Germany                  25.311562
# France                   25.056827
# Spain                    24.779521
# Malta                    24.335625
# Canada                   24.280662
# Iceland                  23.681319
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
# your code here

orders['UnitPrice'].max()
# Out:
# 8142.75

# %% [markdown]
# #### What is the average amount spent per year?

# %%
# your code here

orders.groupby('year')['amount_spent'].mean()
# Out:
# year
# 2010    21.892733
# 2011    22.430074
# Name: amount_spent, dtype: float64
