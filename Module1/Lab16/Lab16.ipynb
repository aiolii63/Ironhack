g>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_DEVELOPERS_PAGE","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":255639672,"originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="091f5d769add53511f4ea6102a80dd49e66abf239efe85dc7f3c3a4f2a08abe5" data-view-component="true" href="/mfussenegger/nvim-dap" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
#       nvim-dap
# </a> </h1>
# <div class="f6 color-fg-muted mt-1">
#       Debug Adapter Protocol client implementation for Neovim (&gt;= 0.5)
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="mr-2">
# <a aria-label="Sponsor @mfussenegger" class="btn btn-sm btn-block" data-hydro-click='{"event_type":"sponsors.button_click","payload":{"button":"TRENDING_DEVELOPER_SPONSOR","sponsorable_login":"mfussenegger","originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="9327c3376b44004e4cd7f65255ab5a66ed8b5d1b7c5d82b0f6942384f2c4568e" data-view-component="true" href="/sponsors/mfussenegger">
# <svg aria-hidden="true" class="octicon octicon-heart icon-sponsor mr-1 v-align-middle color-fg-sponsors anim-pulse-in" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M4.25 2.5c-1.336 0-2.75 1.164-2.75 3 0 2.15 1.58 4.144 3.365 5.682A20.565 20.565 0 008 13.393a20.561 20.561 0 003.135-2.211C12.92 9.644 14.5 7.65 14.5 5.5c0-1.836-1.414-3-2.75-3-1.373 0-2.609.986-3.029 2.456a.75.75 0 01-1.442 0C6.859 3.486 5.623 2.5 4.25 2.5zM8 14.25l-.345.666-.002-.001-.006-.003-.018-.01a7.643 7.643 0 01-.31-.17 22.075 22.075 0 01-3.434-2.414C2.045 10.731 0 8.35 0 5.5 0 2.836 2.086 1 4.25 1 5.797 1 7.153 1.802 8 3.02 8.847 1.802 10.203 1 11.75 1 13.914 1 16 2.836 16 5.5c0 2.85-2.045 5.231-3.885 6.818a22.08 22.08 0 01-3.744 2.584l-.018.01-.006.003h-.002L8 14.25zm0 0l.345.666a.752.752 0 01-.69 0L8 14.25z" fill-rule="evenodd"></path>
# </svg>
# <span class="v-align-middle">Sponsor</span>
# </a>
# </div>
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow d-block">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="758ca9b951a863373b9dca2759329881977e0c89c5a5b03c5cc5efdefcb67f4a" href="/login?return_to=https%3A%2F%2Fgithub.com%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>
# </div>
# </div>
# </div>
# </main>
# </div>
# <footer class="footer width-full container-lg p-responsive" role="contentinfo">
# <div class="position-relative d-flex flex-items-center pb-2 f6 color-fg-muted border-top color-border-muted flex-column-reverse flex-lg-row flex-wrap flex-lg-nowrap mt-6 pt-6">
# <ul class="list-style-none d-flex flex-wrap col-0 col-lg-2 flex-justify-start flex-lg-justify-between mb-2 mb-lg-0">
# <li class="mt-2 mt-lg-0 d-flex flex-items-center">
# <a aria-label="Homepage" class="footer-octicon mr-2" href="https://github.com" title="GitHub">
# <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="24" version="1.1" viewbox="0 0 16 16" width="24">
# <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path>
# </svg>
# </a> <span>
#         © 2022 GitHub, Inc.
#         </span>
# </li>
# </ul>
# <ul class="list-style-none d-flex flex-wrap col-12 col-lg-8 flex-justify-center flex-lg-justify-between mb-2 mb-lg-0">
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to terms","label":"text:terms"}' data-hydro-click='{"event_type":"analytics.event","payload":{"category":"Footer","action":"go to terms","label":"text:terms","originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="1a754ccb557b6ca6efd95046661cf3bbb1ccb77c4fcc0c54a40a8e89caa06b68" href="https://docs.github.com/en/github/site-policy/github-terms-of-service">Terms</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to privacy","label":"text:privacy"}' data-hydro-click='{"event_type":"analytics.event","payload":{"category":"Footer","action":"go to privacy","label":"text:privacy","originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="7e5e93ade69b58cf669bff7e22b2d41472c7bf440c0d99181150e1722d285950" href="https://docs.github.com/en/github/site-policy/github-privacy-statement">Privacy</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to security","label":"text:security"}' data-hydro-click='{"event_type":"analytics.event","payload":{"category":"Footer","action":"go to security","label":"text:security","originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="694e9e8b22eabb91835da316399f3992842b11c0f644e980e4933c4e9ce3f98f" href="https://github.com/security">Security</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to status","label":"text:status"}' data-hydro-click='{"event_type":"analytics.event","payload":{"category":"Footer","action":"go to status","label":"text:status","originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="60749fe30d74cce0c28a21be8daba3179bc9538eb05a87ec489e62bb693853e1" href="https://www.githubstatus.com/">Status</a></li>
# <li class="mr-3 mr-lg-0"><a data-ga-click="Footer, go to help, text:Docs" href="https://docs.github.com">Docs</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to contact","label":"text:contact"}' data-hydro-click='{"event_type":"analytics.event","payload":{"category":"Footer","action":"go to contact","label":"text:contact","originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="818726fdf86f5a7aa16772226970b42cb588bbd62aea8541321e70371c177ab2" href="https://support.github.com?tags=dotcom-footer">Contact GitHub</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to Pricing","label":"text:Pricing"}' data-hydro-click='{"event_type":"analytics.event","payload":{"category":"Footer","action":"go to Pricing","label":"text:Pricing","originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="1bb28813568af565b5f79131b6344ac1294a467dd5292abfcfaced6ddc56b261" href="https://github.com/pricing">Pricing</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to api","label":"text:api"}' data-hydro-click='{"event_type":"analytics.event","payload":{"category":"Footer","action":"go to api","label":"text:api","originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="d0a6e1cbf798a75d0e33008bdffeb0862341cadcd227ac578aa21a9429965037" href="https://docs.github.com">API</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to training","label":"text:training"}' data-hydro-click='{"event_type":"analytics.event","payload":{"category":"Footer","action":"go to training","label":"text:training","originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="da1eb0632756284859636b918b703ab105aa91a1c7b519530dbbb444f96daaf6" href="https://services.github.com">Training</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to blog","label":"text:blog"}' data-hydro-click='{"event_type":"analytics.event","payload":{"category":"Footer","action":"go to blog","label":"text:blog","originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="f3c0d8248e2d0e2618211ec71ee01fa97c2cc4bb1741f7dffd8524be382bce31" href="https://github.blog">Blog</a></li>
# <li><a data-ga-click="Footer, go to about, text:about" href="https://github.com/about">About</a></li>
# </ul>
# </div>
# <div class="d-flex flex-justify-center pb-6">
# <span class="f6 color-fg-muted"></span>
# </div>
# </footer>
# <div class="ajax-error-message flash flash-error" hidden="" id="ajax-error-message">
# <svg aria-hidden="true" class="octicon octicon-alert" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path>
# </svg>
# <button aria-label="Dismiss error" class="flash-close js-ajax-error-dismiss" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button>
#     You can’t perform that action at this time.
#   </div>
# <div class="js-stale-session-flash flash flash-warn flash-banner" hidden="">
# <svg aria-hidden="true" class="octicon octicon-alert" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path>
# </svg>
# <span class="js-stale-session-flash-signed-in" hidden="">You signed in with another tab or window. <a href="">Reload</a> to refresh your session.</span>
# <span class="js-stale-session-flash-signed-out" hidden="">You signed out in another tab or window. <a href="">Reload</a> to refresh your session.</span>
# </div>
# <template id="site-details-dialog">
# <details class="details-reset details-overlay details-overlay-dark lh-default color-fg-default hx_rsm" open="">
# <summary aria-label="Close dialog" role="button"></summary>
# <details-dialog class="Box Box--overlay d-flex flex-column anim-fade-in fast hx_rsm-dialog hx_rsm-modal">
# <button aria-label="Close dialog" class="Box-btn-octicon m-0 btn-octicon position-absolute right-0 top-0" data-close-dialog="" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button>
# <div class="octocat-spinner my-6 js-details-dialog-spinner"></div>
# </details-dialog>
# </details>
# </template>
# <div class="Popover js-hovercard-content position-absolute" style="display: none; outline: none;" tabindex="0">
# <div class="Popover-message Popover-message--bottom-left Popover-message--large Box color-shadow-large" style="width:360px;">
# </div>
# </div>
# <template id="snippet-clipboard-copy-button">
# <div class="zeroclipboard-container position-absolute right-0 top-0">
# <clipboard-copy aria-label="Copy" class="ClipboardButton btn js-clipboard-copy m-2 p-0 tooltipped-no-delay" data-copy-feedback="Copied!" data-tooltip-direction="w">
# <svg aria-hidden="true" class="octicon octicon-copy js-clipboard-copy-icon m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M0 6.75C0 5.784.784 5 1.75 5h1.5a.75.75 0 010 1.5h-1.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 00.25-.25v-1.5a.75.75 0 011.5 0v1.5A1.75 1.75 0 019.25 16h-7.5A1.75 1.75 0 010 14.25v-7.5z" fill-rule="evenodd"></path><path d="M5 1.75C5 .784 5.784 0 6.75 0h7.5C15.216 0 16 .784 16 1.75v7.5A1.75 1.75 0 0114.25 11h-7.5A1.75 1.75 0 015 9.25v-7.5zm1.75-.25a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25h-7.5z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-hidden="true" class="octicon octicon-check js-clipboard-check-icon color-fg-success d-none m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M13.78 4.22a.75.75 0 010 1.06l-7.25 7.25a.75.75 0 01-1.06 0L2.22 9.28a.75.75 0 011.06-1.06L6 10.94l6.72-6.72a.75.75 0 011.06 0z" fill-rule="evenodd"></path>
# </svg>
# </clipboard-copy>
# </div>
# </template>
# </body>
# </html>

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
# your code here
tags = ['p']
text = [element.text for element in soup.find_all(tags)]
print(text)
# Out:
# ['\n      These are the developers building the hot tools today.\n    ', '\n\n              itzg\n ', '\n\n              Jack-Works\n ', '\n\n              arvidn\n ', '\n\n              josegonzalez\n ', '\n\n              LekoArts\n ', '\n\n              lucacasonato\n ', '\n\n              a8m\n ', '\n\n              samber\n ', '\n\n              frenck\n ', '\n\n              yujincheng08\n ', '\n\n              1technophile\n ', '\n\n              jrfnl\n ', '\n\n Advies en zo', '\n\n              tkf\n ', '\n\n              hajimehoshi\n ', '\n\n              rocky\n ', '\n\n              bramkragten\n ', '\n\n              sbc100\n ', '\n\n @google', '\n\n              facontidavide\n ', '\n\n              glenn-jocher\n ', '\n\n @ultralytics', '\n\n              lucasfernog\n ', '\n\n @tauri-apps', '\n\n              kazupon\n ', '\n\n              nlohmann\n ', '\n\n              devxoul\n ', '\n\n              ian\n ', '\n\n              mfussenegger\n ']

# %%
developer = []
for i in text:
    i.replace('\n','')
    i.replace(' ','')
    developer.append(i)
print(''.join(developer))
# Out:
#       These are the developers building the hot tools today.
#
#
#               itzg
#
#
#               Jack-Works
#
#
#               arvidn
#
#
#               josegonzalez
#
#
#               LekoArts
#
#
#               lucacasonato
#
#
#               a8m
#
#
#               samber
#
#
#               frenck
#
#
#               yujincheng08
#
#
#               1technophile
#
#
#               jrfnl
#
#
#  Advies en zo
#
#               tkf
#
#
#               hajimehoshi
#
#
#               rocky
#
#
#               bramkragten
#
#
#               sbc100
#
#
#  @google
#
#               facontidavide
#
#
#               glenn-jocher
#
#
#  @ultralytics
#
#               lucasfernog
#
#
#  @tauri-apps
#
#               kazupon
#
#
#               nlohmann
#
#
#               devxoul
#
#
#               ian
#
#
#               mfussenegger

# %%
list1 =[i.strip().split("\n") for i in developer]
del list1[0]
del list1[9]
del list1[12]
del list1[19]
list2 = []
for i in range(0,len(list1)):
    list2.append(list1[i][0])
list2
# Out:
# ['itzg',
#  'Jack-Works',
#  'arvidn',
#  'josegonzalez',
#  'LekoArts',
#  'lucacasonato',
#  'a8m',
#  'samber',
#  'frenck',
#  '1technophile',
#  'jrfnl',
#  'Advies en zo',
#  'hajimehoshi',
#  'rocky',
#  'bramkragten',
#  'sbc100',
#  '@google',
#  'facontidavide',
#  'glenn-jocher',
#  'lucasfernog',
#  '@tauri-apps',
#  'kazupon',
#  'nlohmann',
#  'devxoul',
#  'ian',
#  'mfussenegger']

# %% [markdown]
# #### Display the trending Python repositories in GitHub.
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
# your code here
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
tags = soup("h1", class_ = "h3 lh-condensed")
list_username_repo = [l.text.replace('\n','').replace(' ','') for l in tags]

print(list_username_repo)
# Out:
# ['GeoffBourne', 'JackWorks', 'ArvidNorberg', 'JoseDiaz-Gonzalez', 'Lennart', 'LucaCasonato', 'ArielMashraki', 'SamuelBerthe', 'FranckNijhof', 'LoveSy', 'Florian', 'Juliette', 'TakafumiArakaki', 'HajimeHoshi', 'R.Bernstein', 'BramKragten', 'SamClegg', 'DavideFaconti', 'GlennJocher', 'LucasFernandesNogueira', 'kazuyakawaguchi', 'NielsLohmann', 'SuyeolJeon', 'IanHunter', 'MathiasFußenegger']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
# your code here
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
list_imgs = soup.find_all("img")
list_imgs_links = ["https:" + l['src'] for l in list_imgs]
print(list_imgs_links)
Image(url=list_imgs_links[6])
# Out:
# ['https:', 'https:', 'https:', 'https:', 'https:https://avatars.githubusercontent.com/u/988985?s=96&v=4', 'https:https://avatars.githubusercontent.com/u/5390719?s=96&v=4', 'https:https://avatars.githubusercontent.com/u/661450?s=96&v=4', 'https:https://avatars.githubusercontent.com/u/65675?s=96&v=4', 'https:https://avatars.githubusercontent.com/u/16143594?s=96&v=4', 'https:https://avatars.githubusercontent.com/u/7829205?s=96&v=4', 'https:https://avatars.githubusercontent.com/u/7413593?s=96&v=4', 'https:https://avatars.githubusercontent.com/u/2951285?s=96&v=4', 'https:https://avatars.githubusercontent.com/u/195327?s=96&v=4', 'https:https://avatars.githubusercontent.com/u/5022927?s=96&v=4', 'https:https://avatars.githubusercontent.com/u/12672732?s=96&v=4', 'https:https://avatars.githubusercontent.com/u/663378?s=96&v=4', 'https:https://avatars.githubusercontent.com/u/29282?s=96&v=4', 'https:https://avatars.githubusercontent.com/u/16950?s=96&v=4', 'https:https://avatars.githubusercontent.com/u/8851?s=96&v=4', 'https:https://avatars.githubusercontent.com/u/5662298?s=96&v=4', 'https:https://avatars.githubusercontent.com/u/515813?s=96&v=4', 'https:https://avatars.githubusercontent.com/u/2822888?s=96&v=4', 'https:https://avatars.githubusercontent.com/u/26833433?s=96&v=4', 'https:https://avatars.githubusercontent.com/u/20051258?s=96&v=4', 'https:https://avatars.githubusercontent.com/u/72989?s=96&v=4', 'https:https://avatars.githubusercontent.com/u/159488?s=96&v=4', 'https:https://avatars.githubusercontent.com/u/931655?s=96&v=4', 'https:https://avatars.githubusercontent.com/u/19853?s=96&v=4', 'https:https://avatars.githubusercontent.com/u/38700?s=96&v=4']
# <img src="https:https://avatars.githubusercontent.com/u/661450?s=96&v=4"/>

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page.

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python'

# %%
# your code here
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
for link in soup.findAll("a"):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# #start-of-content
# https://github.com/
# /signup?ref_cta=Sign+up&ref_loc=header+logged+out&ref_page=%2Ftrending%2Fdevelopers&source=header
# /features
# /mobile
# /features/actions
# /features/codespaces
# /features/packages
# /features/security
# /features/code-review
# /features/issues
# /features/integrations
# /sponsors
# /customer-stories
# /team
# /enterprise
# /explore
# /topics
# /collections
# /trending
# https://lab.github.com/
# https://opensource.guide
# /readme
# /events
# https://github.community
# https://education.github.com
# https://stars.github.com
# /marketplace
# /pricing
# /pricing#compare-features
# https://github.com/enterprise/contact
# https://education.github.com
#
#
#
#
# /login?return_to=https%3A%2F%2Fgithub.com%2Ftrending%2Fdevelopers
# /signup?ref_cta=Sign+up&ref_loc=header+logged+out&ref_page=%2Ftrending%2Fdevelopers&source=header
# /explore
# /topics
# /trending
# /collections
# /events
# /sponsors/community
# /explore/email
# /trending
# /trending/developers
# /trending/developers/c++?since=daily
# /trending/developers/html?since=daily
# /trending/developers/java?since=daily
# /trending/developers/javascript?since=daily
# /trending/developers/php?since=daily
# /trending/developers/python?since=daily
# /trending/developers/ruby?since=daily
# /trending/developers/unknown?since=daily
# /trending/developers/1c-enterprise?since=daily
# /trending/developers/4d?since=daily
# /trending/developers/abap?since=daily
# /trending/developers/abap-cds?since=daily
# /trending/developers/abnf?since=daily
# /trending/developers/actionscript?since=daily
# /trending/developers/ada?since=daily
# /trending/developers/adobe-font-metrics?since=daily
# /trending/developers/agda?since=daily
# /trending/developers/ags-script?since=daily
# /trending/developers/aidl?since=daily
# /trending/developers/al?since=daily
# /trending/developers/al?since=daily
# /trending/developers/alloy?since=daily
# /trending/developers/alpine-abuild?since=daily
# /trending/developers/altium-designer?since=daily
# /trending/developers/ampl?since=daily
# /trending/developers/angelscript?since=daily
# /trending/developers/ant-build-system?since=daily
# /trending/developers/antlr?since=daily
# /trending/developers/apacheconf?since=daily
# /trending/developers/apex?since=daily
# /trending/developers/api-blueprint?since=daily
# /trending/developers/apl?since=daily
# /trending/developers/apollo-guidance-computer?since=daily
# /trending/developers/applescript?since=daily
# /trending/developers/arc?since=daily
# /trending/developers/asciidoc?since=daily
# /trending/developers/asl?since=daily
# /trending/developers/asn.1?since=daily
# /trending/developers/classic-asp?since=daily
# /trending/developers/asp.net?since=daily
# /trending/developers/aspectj?since=daily
# /trending/developers/assembly?since=daily
# /trending/developers/astro?since=daily
# /trending/developers/asymptote?since=daily
# /trending/developers/ats?since=daily
# /trending/developers/augeas?since=daily
# /trending/developers/autohotkey?since=daily
# /trending/developers/autoit?since=daily
# /trending/developers/avro-idl?since=daily
# /trending/developers/awk?since=daily
# /trending/developers/ballerina?since=daily
# /trending/developers/basic?since=daily
# /trending/developers/batchfile?since=daily
# /trending/developers/beef?since=daily
# /trending/developers/befunge?since=daily
# /trending/developers/bibtex?since=daily
# /trending/developers/bicep?since=daily
# /trending/developers/bison?since=daily
# /trending/developers/bitbake?since=daily
# /trending/developers/blade?since=daily
# /trending/developers/blitzbasic?since=daily
# /trending/developers/blitzmax?since=daily
# /trending/developers/bluespec?since=daily
# /trending/developers/boo?since=daily
# /trending/developers/boogie?since=daily
# /trending/developers/brainfuck?since=daily
# /trending/developers/brightscript?since=daily
# /trending/developers/zeek?since=daily
# /trending/developers/browserslist?since=daily
# /trending/developers/c?since=daily
# /trending/developers/c%23?since=daily
# /trending/developers/c-objdump?since=daily
# /trending/developers/c2hs-haskell?since=daily
# /trending/developers/cabal-config?since=daily
# /trending/developers/cap'n-proto?since=daily
# /trending/developers/cartocss?since=daily
# /trending/developers/ceylon?since=daily
# /trending/developers/chapel?since=daily
# /trending/developers/charity?since=daily
# /trending/developers/chuck?since=daily
# /trending/developers/cil?since=daily
# /trending/developers/cirru?since=daily
# /trending/developers/clarion?since=daily
# /trending/developers/clarity?since=daily
# /trending/developers/classic-asp?since=daily
# /trending/developers/clean?since=daily
# /trending/developers/click?since=daily
# /trending/developers/clips?since=daily
# /trending/developers/clojure?since=daily
# /trending/developers/closure-templates?since=daily
# /trending/developers/cloud-firestore-security-rules?since=daily
# /trending/developers/cmake?since=daily
# /trending/developers/cobol?since=daily
# /trending/developers/codeowners?since=daily
# /trending/developers/codeql?since=daily
# /trending/developers/coffeescript?since=daily
# /trending/developers/coldfusion?since=daily
# /trending/developers/coldfusion-cfc?since=daily
# /trending/developers/collada?since=daily
# /trending/developers/common-lisp?since=daily
# /trending/developers/common-workflow-language?since=daily
# /trending/developers/component-pascal?since=daily
# /trending/developers/conll-u?since=daily
# /trending/developers/cool?since=daily
# /trending/developers/coq?since=daily
# /trending/developers/cpp-objdump?since=daily
# /trending/developers/creole?since=daily
# /trending/developers/crystal?since=daily
# /trending/developers/cson?since=daily
# /trending/developers/csound?since=daily
# /trending/developers/csound-document?since=daily
# /trending/developers/csound-score?since=daily
# /trending/developers/css?since=daily
# /trending/developers/csv?since=daily
# /trending/developers/cuda?since=daily
# /trending/developers/cue?since=daily
# /trending/developers/curl-config?since=daily
# /trending/developers/curry?since=daily
# /trending/developers/cweb?since=daily
# /trending/developers/cycript?since=daily
# /trending/developers/cython?since=daily
# /trending/developers/d?since=daily
# /trending/developers/d-objdump?since=daily
# /trending/developers/dafny?since=daily
# /trending/developers/darcs-patch?since=daily
# /trending/developers/dart?since=daily
# /trending/developers/dataweave?since=daily
# /trending/developers/denizenscript?since=daily
# /trending/developers/desktop?since=daily
# /trending/developers/dhall?since=daily
# /trending/developers/diff?since=daily
# /trending/developers/digital-command-language?since=daily
# /trending/developers/dircolors?since=daily
# /trending/developers/directx-3d-file?since=daily
# /trending/developers/dm?since=daily
# /trending/developers/dns-zone?since=daily
# /trending/developers/dockerfile?since=daily
# /trending/developers/dogescript?since=daily
# /trending/developers/dtrace?since=daily
# /trending/developers/dylan?since=daily
# /trending/developers/e?since=daily
# /trending/developers/e-mail?since=daily
# /trending/developers/eagle?since=daily
# /trending/developers/earthly?since=daily
# /trending/developers/easybuild?since=daily
# /trending/developers/ebnf?since=daily
# /trending/developers/ec?since=daily
# /trending/developers/ecere-projects?since=daily
# /trending/developers/ecl?since=daily
# /trending/developers/eclipse?since=daily
# /trending/developers/editorconfig?since=daily
# /trending/developers/edje-data-collection?since=daily
# /trending/developers/edn?since=daily
# /trending/developers/eiffel?since=daily
# /trending/developers/ejs?since=daily
# /trending/developers/elixir?since=daily
# /trending/developers/elm?since=daily
# /trending/developers/emacs-lisp?since=daily
# /trending/developers/emberscript?since=daily
# /trending/developers/e-mail?since=daily
# /trending/developers/eq?since=daily
# /trending/developers/erlang?since=daily
# /trending/developers/euphoria?since=daily
# /trending/developers/f%23?since=daily
# /trending/developers/f*?since=daily
# /trending/developers/factor?since=daily
# /trending/developers/fancy?since=daily
# /trending/developers/fantom?since=daily
# /trending/developers/faust?since=daily
# /trending/developers/fennel?since=daily
# /trending/developers/figlet-font?since=daily
# /trending/developers/filebench-wml?since=daily
# /trending/developers/filterscript?since=daily
# /trending/developers/fish?since=daily
# /trending/developers/fluent?since=daily
# /trending/developers/flux?since=daily
# /trending/developers/formatted?since=daily
# /trending/developers/forth?since=daily
# /trending/developers/fortran?since=daily
# /trending/developers/fortran-free-form?since=daily
# /trending/developers/freebasic?since=daily
# /trending/developers/freemarker?since=daily
# /trending/developers/frege?since=daily
# /trending/developers/futhark?since=daily
# /trending/developers/g-code?since=daily
# /trending/developers/game-maker-language?since=daily
# /trending/developers/gaml?since=daily
# /trending/developers/gams?since=daily
# /trending/developers/gap?since=daily
# /trending/developers/gcc-machine-description?since=daily
# /trending/developers/gdb?since=daily
# /trending/developers/gdscript?since=daily
# /trending/developers/gedcom?since=daily
# /trending/developers/gemfile.lock?since=daily
# /trending/developers/genie?since=daily
# /trending/developers/genshi?since=daily
# /trending/developers/gentoo-ebuild?since=daily
# /trending/developers/gentoo-eclass?since=daily
# /trending/developers/gerber-image?since=daily
# /trending/developers/gettext-catalog?since=daily
# /trending/developers/gherkin?since=daily
# /trending/developers/git-attributes?since=daily
# /trending/developers/git-config?since=daily
# /trending/developers/gleam?since=daily
# /trending/developers/glsl?since=daily
# /trending/developers/glyph?since=daily
# /trending/developers/glyph-bitmap-distribution-format?since=daily
# /trending/developers/gn?since=daily
# /trending/developers/gnuplot?since=daily
# /trending/developers/go?since=daily
# /trending/developers/go-checksums?since=daily
# /trending/developers/go-module?since=daily
# /trending/developers/golo?since=daily
# /trending/developers/gosu?since=daily
# /trending/developers/grace?since=daily
# /trending/developers/gradle?since=daily
# /trending/developers/grammatical-framework?since=daily
# /trending/developers/graph-modeling-language?since=daily
# /trending/developers/graphql?since=daily
# /trending/developers/graphviz-(dot)?since=daily
# /trending/developers/groovy?since=daily
# /trending/developers/groovy-server-pages?since=daily
# /trending/developers/gsc?since=daily
# /trending/developers/hack?since=daily
# /trending/developers/haml?since=daily
# /trending/developers/handlebars?since=daily
# /trending/developers/haproxy?since=daily
# /trending/developers/harbour?since=daily
# /trending/developers/haskell?since=daily
# /trending/developers/haxe?since=daily
# /trending/developers/hcl?since=daily
# /trending/developers/hiveql?since=daily
# /trending/developers/hlsl?since=daily
# /trending/developers/holyc?since=daily
# /trending/developers/hoon?since=daily
# /trending/developers/jinja?since=daily
# /trending/developers/html+ecr?since=daily
# /trending/developers/html+eex?since=daily
# /trending/developers/html+erb?since=daily
# /trending/developers/html+php?since=daily
# /trending/developers/html+razor?since=daily
# /trending/developers/http?since=daily
# /trending/developers/hxml?since=daily
# /trending/developers/hy?since=daily
# /trending/developers/hyphy?since=daily
# /trending/developers/idl?since=daily
# /trending/developers/idris?since=daily
# /trending/developers/ignore-list?since=daily
# /trending/developers/igor-pro?since=daily
# /trending/developers/imagej-macro?since=daily
# /trending/developers/inform-7?since=daily
# /trending/developers/ini?since=daily
# /trending/developers/inno-setup?since=daily
# /trending/developers/io?since=daily
# /trending/developers/ioke?since=daily
# /trending/developers/irc-log?since=daily
# /trending/developers/isabelle?since=daily
# /trending/developers/isabelle-root?since=daily
# /trending/developers/j?since=daily
# /trending/developers/janet?since=daily
# /trending/developers/jasmin?since=daily
# /trending/developers/java-properties?since=daily
# /trending/developers/java-server-pages?since=daily
# /trending/developers/javascript+erb?since=daily
# /trending/developers/jflex?since=daily
# /trending/developers/jinja?since=daily
# /trending/developers/jison?since=daily
# /trending/developers/jison-lex?since=daily
# /trending/developers/jolie?since=daily
# /trending/developers/jq?since=daily
# /trending/developers/json?since=daily
# /trending/developers/json-with-comments?since=daily
# /trending/developers/json5?since=daily
# /trending/developers/jsoniq?since=daily
# /trending/developers/jsonld?since=daily
# /trending/developers/jsonnet?since=daily
# /trending/developers/julia?since=daily
# /trending/developers/jupyter-notebook?since=daily
# /trending/developers/kaitai-struct?since=daily
# /trending/developers/kakounescript?since=daily
# /trending/developers/kicad-layout?since=daily
# /trending/developers/kicad-legacy-layout?since=daily
# /trending/developers/kicad-schematic?since=daily
# /trending/developers/kit?since=daily
# /trending/developers/kotlin?since=daily
# /trending/developers/krl?since=daily
# /trending/developers/kusto?since=daily
# /trending/developers/kvlang?since=daily
# /trending/developers/labview?since=daily
# /trending/developers/lark?since=daily
# /trending/developers/lasso?since=daily
# /trending/developers/latte?since=daily
# /trending/developers/lean?since=daily
# /trending/developers/less?since=daily
# /trending/developers/lex?since=daily
# /trending/developers/lfe?since=daily
# /trending/developers/lilypond?since=daily
# /trending/developers/limbo?since=daily
# /trending/developers/linker-script?since=daily
# /trending/developers/linux-kernel-module?since=daily
# /trending/developers/liquid?since=daily
# /trending/developers/literate-agda?since=daily
# /trending/developers/literate-coffeescript?since=daily
# /trending/developers/literate-haskell?since=daily
# /trending/developers/livescript?since=daily
# /trending/developers/llvm?since=daily
# /trending/developers/logos?since=daily
# /trending/developers/logtalk?since=daily
# /trending/developers/lolcode?since=daily
# /trending/developers/lookml?since=daily
# /trending/developers/loomscript?since=daily
# /trending/developers/lsl?since=daily
# /trending/developers/ltspice-symbol?since=daily
# /trending/developers/lua?since=daily
# /trending/developers/m?since=daily
# /trending/developers/m4?since=daily
# /trending/developers/m4sugar?since=daily
# /trending/developers/macaulay2?since=daily
# /trending/developers/makefile?since=daily
# /trending/developers/mako?since=daily
# /trending/developers/markdown?since=daily
# /trending/developers/marko?since=daily
# /trending/developers/mask?since=daily
# /trending/developers/mathematica?since=daily
# /trending/developers/matlab?since=daily
# /trending/developers/maven-pom?since=daily
# /trending/developers/max?since=daily
# /trending/developers/maxscript?since=daily
# /trending/developers/mcfunction?since=daily
# /trending/developers/wikitext?since=daily
# /trending/developers/mercury?since=daily
# /trending/developers/meson?since=daily
# /trending/developers/metal?since=daily
# /trending/developers/microsoft-developer-studio-project?since=daily
# /trending/developers/microsoft-visual-studio-solution?since=daily
# /trending/developers/minid?since=daily
# /trending/developers/mint?since=daily
# /trending/developers/mirah?since=daily
# /trending/developers/mirc-script?since=daily
# /trending/developers/mlir?since=daily
# /trending/developers/modelica?since=daily
# /trending/developers/modula-2?since=daily
# /trending/developers/modula-3?since=daily
# /trending/developers/module-management-system?since=daily
# /trending/developers/monkey?since=daily
# /trending/developers/moocode?since=daily
# /trending/developers/moonscript?since=daily
# /trending/developers/motoko?since=daily
# /trending/developers/motorola-68k-assembly?since=daily
# /trending/developers/mql4?since=daily
# /trending/developers/mql5?since=daily
# /trending/developers/mtml?since=daily
# /trending/developers/muf?since=daily
# /trending/developers/mupad?since=daily
# /trending/developers/muse?since=daily
# /trending/developers/mustache?since=daily
# /trending/developers/myghty?since=daily
# /trending/developers/nanorc?since=daily
# /trending/developers/nasl?since=daily
# /trending/developers/ncl?since=daily
# /trending/developers/nearley?since=daily
# /trending/developers/nemerle?since=daily
# /trending/developers/neon?since=daily
# /trending/developers/nesc?since=daily
# /trending/developers/netlinx?since=daily
# /trending/developers/netlinx+erb?since=daily
# /trending/developers/netlogo?since=daily
# /trending/developers/newlisp?since=daily
# /trending/developers/nextflow?since=daily
# /trending/developers/nginx?since=daily
# /trending/developers/nim?since=daily
# /trending/developers/ninja?since=daily
# /trending/developers/nit?since=daily
# /trending/developers/nix?since=daily
# /trending/developers/nl?since=daily
# /trending/developers/npm-config?since=daily
# /trending/developers/nsis?since=daily
# /trending/developers/nu?since=daily
# /trending/developers/numpy?since=daily
# /trending/developers/nunjucks?since=daily
# /trending/developers/nwscript?since=daily
# /trending/developers/objdump?since=daily
# /trending/developers/object-data-instance-notation?since=daily
# /trending/developers/objective-c?since=daily
# /trending/developers/objective-c++?since=daily
# /trending/developers/objective-j?since=daily
# /trending/developers/objectscript?since=daily
# /trending/developers/ocaml?since=daily
# /trending/developers/odin?since=daily
# /trending/developers/omgrofl?since=daily
# /trending/developers/ooc?since=daily
# /trending/developers/opa?since=daily
# /trending/developers/opal?since=daily
# /trending/developers/open-policy-agent?since=daily
# /trending/developers/opencl?since=daily
# /trending/developers/openedge-abl?since=daily
# /trending/developers/openqasm?since=daily
# /trending/developers/openrc-runscript?since=daily
# /trending/developers/openscad?since=daily
# /trending/developers/openstep-property-list?since=daily
# /trending/developers/opentype-feature-file?since=daily
# /trending/developers/org?since=daily
# /trending/developers/ox?since=daily
# /trending/developers/oxygene?since=daily
# /trending/developers/oz?since=daily
# /trending/developers/p4?since=daily
# /trending/developers/pan?since=daily
# /trending/developers/papyrus?since=daily
# /trending/developers/parrot?since=daily
# /trending/developers/parrot-assembly?since=daily
# /trending/developers/parrot-internal-representation?since=daily
# /trending/developers/pascal?since=daily
# /trending/developers/pawn?since=daily
# /trending/developers/peg.js?since=daily
# /trending/developers/pep8?since=daily
# /trending/developers/perl?since=daily
# /trending/developers/pic?since=daily
# /trending/developers/pickle?since=daily
# /trending/developers/picolisp?since=daily
# /trending/developers/piglatin?since=daily
# /trending/developers/pike?since=daily
# /trending/developers/plantuml?since=daily
# /trending/developers/plpgsql?since=daily
# /trending/developers/plsql?since=daily
# /trending/developers/pod?since=daily
# /trending/developers/pod-6?since=daily
# /trending/developers/pogoscript?since=daily
# /trending/developers/pony?since=daily
# /trending/developers/postcss?since=daily
# /trending/developers/postscript?since=daily
# /trending/developers/pov-ray-sdl?since=daily
# /trending/developers/powerbuilder?since=daily
# /trending/developers/powershell?since=daily
# /trending/developers/prisma?since=daily
# /trending/developers/processing?since=daily
# /trending/developers/procfile?since=daily
# /trending/developers/proguard?since=daily
# /trending/developers/prolog?since=daily
# /trending/developers/promela?since=daily
# /trending/developers/propeller-spin?since=daily
# /trending/developers/protocol-buffer?since=daily
# /trending/developers/public-key?since=daily
# /trending/developers/pug?since=daily
# /trending/developers/puppet?since=daily
# /trending/developers/pure-data?since=daily
# /trending/developers/purebasic?since=daily
# /trending/developers/purescript?since=daily
# /trending/developers/python-console?since=daily
# /trending/developers/python-traceback?since=daily
# /trending/developers/q?since=daily
# /trending/developers/q%23?since=daily
# /trending/developers/qmake?since=daily
# /trending/developers/qml?since=daily
# /trending/developers/qt-script?since=daily
# /trending/developers/quake?since=daily
# /trending/developers/r?since=daily
# /trending/developers/racket?since=daily
# /trending/developers/ragel?since=daily
# /trending/developers/raku?since=daily
# /trending/developers/raml?since=daily
# /trending/developers/rascal?since=daily
# /trending/developers/raw-token-data?since=daily
# /trending/developers/rdoc?since=daily
# /trending/developers/readline-config?since=daily
# /trending/developers/realbasic?since=daily
# /trending/developers/reason?since=daily
# /trending/developers/rebol?since=daily
# /trending/developers/red?since=daily
# /trending/developers/redcode?since=daily
# /trending/developers/regular-expression?since=daily
# /trending/developers/ren'py?since=daily
# /trending/developers/renderscript?since=daily
# /trending/developers/rescript?since=daily
# /trending/developers/restructuredtext?since=daily
# /trending/developers/rexx?since=daily
# /trending/developers/rich-text-format?since=daily
# /trending/developers/ring?since=daily
# /trending/developers/riot?since=daily
# /trending/developers/rmarkdown?since=daily
# /trending/developers/robotframework?since=daily
# /trending/developers/robots.txt?since=daily
# /trending/developers/roff?since=daily
# /trending/developers/roff-manpage?since=daily
# /trending/developers/rouge?since=daily
# /trending/developers/rpc?since=daily
# /trending/developers/rpgle?since=daily
# /trending/developers/rpm-spec?since=daily
# /trending/developers/runoff?since=daily
# /trending/developers/rust?since=daily
# /trending/developers/sage?since=daily
# /trending/developers/saltstack?since=daily
# /trending/developers/sas?since=daily
# /trending/developers/sass?since=daily
# /trending/developers/scala?since=daily
# /trending/developers/scaml?since=daily
# /trending/developers/scheme?since=daily
# /trending/developers/scilab?since=daily
# /trending/developers/scss?since=daily
# /trending/developers/sed?since=daily
# /trending/developers/self?since=daily
# /trending/developers/selinux-policy?since=daily
# /trending/developers/shaderlab?since=daily
# /trending/developers/shell?since=daily
# /trending/developers/shellcheck-config?since=daily
# /trending/developers/shellsession?since=daily
# /trending/developers/shen?since=daily
# /trending/developers/sieve?since=daily
# /trending/developers/singularity?since=daily
# /trending/developers/slash?since=daily
# /trending/developers/slice?since=daily
# /trending/developers/slim?since=daily
# /trending/developers/smali?since=daily
# /trending/developers/smalltalk?since=daily
# /trending/developers/smarty?since=daily
# /trending/developers/smpl?since=daily
# /trending/developers/smt?since=daily
# /trending/developers/solidity?since=daily
# /trending/developers/sourcepawn?since=daily
# /trending/developers/sparql?since=daily
# /trending/developers/spline-font-database?since=daily
# /trending/developers/sqf?since=daily
# /trending/developers/sql?since=daily
# /trending/developers/sqlpl?since=daily
# /trending/developers/squirrel?since=daily
# /trending/developers/srecode-template?since=daily
# /trending/developers/ssh-config?since=daily
# /trending/developers/stan?since=daily
# /trending/developers/standard-ml?since=daily
# /trending/developers/starlark?since=daily
# /trending/developers/stata?since=daily
# /trending/developers/ston?since=daily
# /trending/developers/stringtemplate?since=daily
# /trending/developers/stylus?since=daily
# /trending/developers/subrip-text?since=daily
# /trending/developers/sugarss?since=daily
# /trending/developers/supercollider?since=daily
# /trending/developers/svelte?since=daily
# /trending/developers/svg?since=daily
# /trending/developers/swift?since=daily
# /trending/developers/swig?since=daily
# /trending/developers/systemverilog?since=daily
# /trending/developers/tcl?since=daily
# /trending/developers/tcsh?since=daily
# /trending/developers/tea?since=daily
# /trending/developers/terra?since=daily
# /trending/developers/tex?since=daily
# /trending/developers/texinfo?since=daily
# /trending/developers/text?since=daily
# /trending/developers/textile?since=daily
# /trending/developers/thrift?since=daily
# /trending/developers/ti-program?since=daily
# /trending/developers/tla?since=daily
# /trending/developers/toml?since=daily
# /trending/developers/tsql?since=daily
# /trending/developers/tsv?since=daily
# /trending/developers/tsx?since=daily
# /trending/developers/turing?since=daily
# /trending/developers/turtle?since=daily
# /trending/developers/twig?since=daily
# /trending/developers/txl?since=daily
# /trending/developers/type-language?since=daily
# /trending/developers/typescript?since=daily
# /trending/developers/unified-parallel-c?since=daily
# /trending/developers/unity3d-asset?since=daily
# /trending/developers/unix-assembly?since=daily
# /trending/developers/uno?since=daily
# /trending/developers/unrealscript?since=daily
# /trending/developers/urweb?since=daily
# /trending/developers/v?since=daily
# /trending/developers/vala?since=daily
# /trending/developers/valve-data-format?since=daily
# /trending/developers/vba?since=daily
# /trending/developers/vbscript?since=daily
# /trending/developers/vcl?since=daily
# /trending/developers/verilog?since=daily
# /trending/developers/vhdl?since=daily
# /trending/developers/vim-help-file?since=daily
# /trending/developers/vim-script?since=daily
# /trending/developers/vim-snippet?since=daily
# /trending/developers/visual-basic-.net?since=daily
# /trending/developers/visual-basic-.net?since=daily
# /trending/developers/volt?since=daily
# /trending/developers/vue?since=daily
# /trending/developers/vyper?since=daily
# /trending/developers/wavefront-material?since=daily
# /trending/developers/wavefront-object?since=daily
# /trending/developers/wdl?since=daily
# /trending/developers/web-ontology-language?since=daily
# /trending/developers/webassembly?since=daily
# /trending/developers/webidl?since=daily
# /trending/developers/webvtt?since=daily
# /trending/developers/wget-config?since=daily
# /trending/developers/wikitext?since=daily
# /trending/developers/windows-registry-entries?since=daily
# /trending/developers/wisp?since=daily
# /trending/developers/witcher-script?since=daily
# /trending/developers/wollok?since=daily
# /trending/developers/world-of-warcraft-addon-data?since=daily
# /trending/developers/x-bitmap?since=daily
# /trending/developers/x-font-directory-index?since=daily
# /trending/developers/x-pixmap?since=daily
# /trending/developers/x10?since=daily
# /trending/developers/xbase?since=daily
# /trending/developers/xc?since=daily
# /trending/developers/xcompose?since=daily
# /trending/developers/xml?since=daily
# /trending/developers/xml-property-list?since=daily
# /trending/developers/xojo?since=daily
# /trending/developers/xonsh?since=daily
# /trending/developers/xpages?since=daily
# /trending/developers/xproc?since=daily
# /trending/developers/xquery?since=daily
# /trending/developers/xs?since=daily
# /trending/developers/xslt?since=daily
# /trending/developers/xtend?since=daily
# /trending/developers/yacc?since=daily
# /trending/developers/yaml?since=daily
# /trending/developers/yang?since=daily
# /trending/developers/yara?since=daily
# /trending/developers/yasnippet?since=daily
# /trending/developers/zap?since=daily
# /trending/developers/zeek?since=daily
# /trending/developers/zenscript?since=daily
# /trending/developers/zephir?since=daily
# /trending/developers/zig?since=daily
# /trending/developers/zil?since=daily
# /trending/developers/zimpl?since=daily
# https://github.com/trending/developers?since=daily
# https://github.com/trending/developers?since=weekly
# https://github.com/trending/developers?since=monthly
# #pa-itzg
# /itzg
# /itzg
# /itzg
# /itzg/docker-minecraft-server
# /login?return_to=https%3A%2F%2Fgithub.com%2Ftrending%2Fdevelopers
# #pa-Jack-Works
# /Jack-Works
# /Jack-Works
# /Jack-Works
# /Jack-Works/async-call-rpc
# /login?return_to=https%3A%2F%2Fgithub.com%2Ftrending%2Fdevelopers
# #pa-arvidn
# /arvidn
# /arvidn
# /arvidn
# /arvidn/libtorrent
# /sponsors/arvidn
# /login?return_to=https%3A%2F%2Fgithub.com%2Ftrending%2Fdevelopers
# #pa-josegonzalez
# /josegonzalez
# /josegonzalez
# /josegonzalez
# /josegonzalez/python-github-backup
# /login?return_to=https%3A%2F%2Fgithub.com%2Ftrending%2Fdevelopers
# #pa-LekoArts
# /LekoArts
# /LekoArts
# /LekoArts
# /LekoArts/gatsby-themes
# /sponsors/LekoArts
# /login?return_to=https%3A%2F%2Fgithub.com%2Ftrending%2Fdevelopers
# #pa-lucacasonato
# /lucacasonato
# /lucacasonato
# /lucacasonato
# /lucacasonato/fresh
# /sponsors/lucacasonato
# /login?return_to=https%3A%2F%2Fgithub.com%2Ftrending%2Fdevelopers
# #pa-a8m
# /a8m
# /a8m
# /a8m
# /a8m/golang-cheat-sheet
# /login?return_to=https%3A%2F%2Fgithub.com%2Ftrending%2Fdevelopers
# #pa-samber
# /samber
# /samber
# /samber
# /samber/lo
# /login?return_to=https%3A%2F%2Fgithub.com%2Ftrending%2Fdevelopers
# #pa-frenck
# /frenck
# /frenck
# /frenck
# /frenck/awesome-home-assistant
# /sponsors/frenck
# /login?return_to=https%3A%2F%2Fgithub.com%2Ftrending%2Fdevelopers
# #pa-yujincheng08
# /yujincheng08
# /yujincheng08
# /yujincheng08
# /yujincheng08/BiliRoaming
# /sponsors/yujincheng08
# /login?return_to=https%3A%2F%2Fgithub.com%2Ftrending%2Fdevelopers
# #pa-1technophile
# /1technophile
# /1technophile
# /1technophile
# /1technophile/OpenMQTTGateway
# /login?return_to=https%3A%2F%2Fgithub.com%2Ftrending%2Fdevelopers
# #pa-jrfnl
# /jrfnl
# /jrfnl
# /jrfnl
# /login?return_to=https%3A%2F%2Fgithub.com%2Ftrending%2Fdevelopers
# #pa-tkf
# /tkf
# /tkf
# /tkf
# /tkf/JuliaCLI.jl
# /login?return_to=https%3A%2F%2Fgithub.com%2Ftrending%2Fdevelopers
# #pa-hajimehoshi
# /hajimehoshi
# /hajimehoshi
# /hajimehoshi
# /hajimehoshi/ebiten
# /sponsors/hajimehoshi
# /login?return_to=https%3A%2F%2Fgithub.com%2Ftrending%2Fdevelopers
# #pa-rocky
# /rocky
# /rocky
# /rocky
# /rocky/python-uncompyle6
# /sponsors/rocky
# /login?return_to=https%3A%2F%2Fgithub.com%2Ftrending%2Fdevelopers
# #pa-bramkragten
# /bramkragten
# /bramkragten
# /bramkragten
# /bramkragten/weather-card
# /sponsors/bramkragten
# /login?return_to=https%3A%2F%2Fgithub.com%2Ftrending%2Fdevelopers
# #pa-sbc100
# /sbc100
# /sbc100
# /sbc100
# /login?return_to=https%3A%2F%2Fgithub.com%2Ftrending%2Fdevelopers
# #pa-facontidavide
# /facontidavide
# /facontidavide
# /facontidavide
# /facontidavide/PlotJuggler
# /sponsors/facontidavide
# /login?return_to=https%3A%2F%2Fgithub.com%2Ftrending%2Fdevelopers
# #pa-glenn-jocher
# /glenn-jocher
# /glenn-jocher
# /glenn-jocher
# /sponsors/glenn-jocher
# /login?return_to=https%3A%2F%2Fgithub.com%2Ftrending%2Fdevelopers
# #pa-lucasfernog
# /lucasfernog
# /lucasfernog
# /lucasfernog
# /login?return_to=https%3A%2F%2Fgithub.com%2Ftrending%2Fdevelopers
# #pa-kazupon
# /kazupon
# /kazupon
# /kazupon
# /kazupon/vue-i18n
# /sponsors/kazupon
# /login?return_to=https%3A%2F%2Fgithub.com%2Ftrending%2Fdevelopers
# #pa-nlohmann
# /nlohmann
# /nlohmann
# /nlohmann
# /nlohmann/json
# /sponsors/nlohmann
# /login?return_to=https%3A%2F%2Fgithub.com%2Ftrending%2Fdevelopers
# #pa-devxoul
# /devxoul
# /devxoul
# /devxoul
# /devxoul/Then
# /login?return_to=https%3A%2F%2Fgithub.com%2Ftrending%2Fdevelopers
# #pa-ian
# /ian
# /ian
# /ian
# /ian/learnnextjs.com
# /login?return_to=https%3A%2F%2Fgithub.com%2Ftrending%2Fdevelopers
# #pa-mfussenegger
# /mfussenegger
# /mfussenegger
# /mfussenegger
# /mfussenegger/nvim-dap
# /sponsors/mfussenegger
# /login?return_to=https%3A%2F%2Fgithub.com%2Ftrending%2Fdevelopers
# https://github.com
# https://docs.github.com/en/github/site-policy/github-terms-of-service
# https://docs.github.com/en/github/site-policy/github-privacy-statement
# https://github.com/security
# https://www.githubstatus.com/
# https://docs.github.com
# https://support.github.com?tags=dotcom-footer
# https://github.com/pricing
# https://docs.github.com
# https://services.github.com
# https://github.blog
# https://github.com/about

# %% [markdown]
# #### Find the number of titles that have changed in the United States Code since its last release point.

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %%
# your code here
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
list1 = soup.text.strip(' ').split("\n")
print(list1)
# Out:
# ['', '', '', '', '', '', '', '', '', '', '            This page is better viewed with a JavaScript enabled browser.', '        ', '', '', '', '', '', '                    Home', '', '', '', ' ', '', '', '', '', '', '\t                    Search & Browse', '\t                ', '', '', '', ' ', '', '', '', '', '', '\t                    Currency and Updating', '\t                ', '', '', '', ' ', '', '', '', '', '', '\t                    Classification Tables', '\t                ', '', '', '', ' ', '', '', '', '', '', '\t                    Popular Name Tool', '\t                ', '', '', '', ' ', '', '', '', '', '', '\t                    Other OLRC Tables and Tools', '\t                ', '', '', '', ' ', '', '', '', '', '', '\t                    Cite Checker', '\t                ', '', '', '', ' ', '', '', '', '', '', '\t                    Table III - Statutes at Large', '\t                ', '', '', '', ' ', '', '', '', '', '', '\t                    Other Tables', '\t                ', '', '', '', ' ', '', '', '', '', '', '\t                    Understanding the Code', '\t                ', '', '', '', ' ', '', '', '', '', '', '\t                    About the Code and Website', '\t                ', '', '', '', ' ', '', '', '', '', '', '\t                    About Classification', '\t                ', '', '', '', ' ', '', '', '', '', '', '\t                    Detailed Guide to the Code', '\t                ', '', '', '', ' ', '', '', '', '', '', '\t                    FAQ and Glossary', '\t                ', '', '', '', ' ', '', '', '', '', '', '\t                    Positive Law Codification', '\t                ', '', '', '', ' ', '', '', '', '', '', '\t                    Editorial Reclassification', '\t                ', '', '', '', ' ', '', '', '', '', '', '\t                    Downloads', '\t                ', '', '', '', ' ', '', '', '', '', '', '\t                    Other Legislative Resources', '\t                ', '', '', '', ' ', '', '', '', '', '', '\t                    CONGRESS.GOV', '\t                ', '', '', '', ' ', '', '', '', '', '', '\t                    govinfo', '\t                ', '', '', '', ' ', '', '', '', '', '', '\t                    HOLC Statutory Compilations', '\t                ', '', '', '', '', '', '', '', 'DOWNLOAD THE UNITED STATES CODE', '', '', 'Current Release Point', 'Public Law 117-80 (12/27/2021)', '', 'Each update of the United States Code is a release point. This page provides downloadable files for the current release point. All files are current through Public Law 117-80 (12/27/2021). Titles in bold have been changed since the last release point.', '', 'A User Guide and the USLM Schema and stylesheet are provided for the United States Code in XML. A stylesheet is provided for the XHTML. PCC files are text files containing GPO photocomposition codes (i.e., locators).', '', 'Information about the currency of United States Code titles is available on the Currency page.  Files for prior release points are available on the Prior Release Points page. Older materials are available on the Annual Historical Archives page.', '', '', '', '', '', '', '          All titles in the format selected compressed into a zip archive.', '', '        ', '', '', '          \xa0', '', '        ', '', '[XML]\xa0[XHTML]\xa0[PCC]\xa0[PDF]', '', '', '', '', '', '             \xa0', '', '\t        ', '', '', '\t          \xa0', '', '\t        ', '', '', '          \xa0', '', '\t        ', '', '', '', '', '             Individual Titles ', '', '\t        ', '', '', '\t          Current Through', '', '\t        ', '', '', '          \xa0', '', '\t        ', '', '', '', '', '          Title 1 - General Provisions ٭', '', '', '', '          117-80', '', '        ', '', '[XML]\xa0[XHTML]\xa0[PCC]\xa0[PDF]', '', '', '', '', '', '          Title 2 - The Congress', '', '        ', '', '', '          117-80', '', '        ', '', '[XML]\xa0[XHTML]\xa0[PCC]\xa0[PDF]', '', '', '', '', '', '           ...

# %%
title_list=[]
for i in list1:
    if i.lstrip().startswith('Title'):
        title_list.append(i.lstrip())
for i in title_list:
    if '٭'in i:
        title_list1.append(i)
len(title_list1)
# Out:
# 27

# %% [markdown]
# #### Find a Python list with the top ten FBI's Most Wanted names.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
# your code here
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
tags = ['h3']
text = [element.text for element in soup.find_all(tags)]
text1 =[]
for i in text:
    text1.append(i.replace('\n',''))
print(text1[0:9])
# Out:
# ['ARNOLDO JIMENEZ', 'JASON DEREK BROWN', 'ALEXIS FLORES', 'JOSE RODOLFO VILLARREAL-HERNANDEZ', 'RAFAEL CARO-QUINTERO', 'YULAN ADONAY ARCHAGA CARIAS', 'EUGENE PALMER', 'BHADRESHKUMAR CHETANBHAI PATEL', 'ALEJANDRO ROSALES CASTILLO']

# %% [markdown]
# ####  Display the 20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
# your code here
html = requests.get(url)
if html.status_code == 200:
    soup = BeautifulSoup(html.content, "lxml")

url = 'https://www.emsc-csem.org/Earthquake/'
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
tags = soup('tr', class_ = 'normal', limit =20)
tags[0].text
# Out:
# 'earthquake2022-03-07\xa0\xa0\xa021:28:21.320min ago38.48\xa0N\xa0\xa0121.76\xa0W\xa0\xa05Md2.4\xa0NORTHERN CALIFORNIA2022-03-07 21:29'

# %%
import re
m = tags[0].find("td", class_ = "tabev6")
m.a.text[:m.a.text.find("   ")].split('\xa0\xa0\xa0')
latitude = [i[0].text for i in [item.find_all("td", class_ = "tabev1") for item in tags]]
longtitude = [i[1].text for i in [item.find_all("td", class_ = "tabev1") for item in tags]]
region = [i.text for i in [l.find("td", class_ = "tb_region") for l in tags]]
date = [item.a.text[:m.a.text.find("   ")].split('\xa0\xa0\xa0')[0] for item in [l.find("td", class_ = "tabev6") for l in tags]] 
time = [item.a.text[:m.a.text.find("   ")].split('\xa0\xa0\xa0')[1] for item in [l.find("td", class_ = "tabev6") for l in tags]]
data ={"date" : date, "time" : time, "latitude" : latitude, "longtitude" : longtitude, "region" : region}
df = pd.DataFrame(data)
df
# Out:
#           date       time latitude longtitude  \
# 0   2022-03-07  21:28:21.   38.48     121.76
# 1   2022-03-07  21:18:56.   14.11     124.95
# 2   2022-03-07  21:08:45.   36.79       2.88
# 3   2022-03-07  21:00:00.   37.00     178.83
# 4   2022-03-07  20:59:18.    0.58      99.71
# 5   2022-03-07  20:54:01.   43.96       7.66
# 6   2022-03-07  20:17:29.   33.35     116.98
# 7   2022-03-07  20:16:18.   38.77      43.17
# 8   2022-03-07  20:12:45.    5.75      78.69
# 9   2022-03-07  19:59:56.   45.01     167.49
# 10  2022-03-07  19:21:18.   19.23     155.38
# 11  2022-03-07  19:19:42.   38.60      29.50
# 12  2022-03-07  19:08:08.   19.87     133.84
# 13  2022-03-07  19:01:31.   37.07     143.18
# 14  2022-03-07  18:48:14.   37.11     177.44
# 15  2022-03-07  18:43:54.   29.19      71.35
# 16  2022-03-07  18:40:58.   35.49       3.61
# 17  2022-03-07  18:36:29.    8.11     122.45
# 18  2022-03-07  18:35:16.    8.15     122.44
# 19  2022-03-07  18:34:28.    6.77      73.04
#
#                               region
# 0                NORTHERN CALIFORNIA
# 1           CATANDUANES, PHILIPPINES
# 2                STRAIT OF GIBRALTAR
# 3    OFF E. COAST OF N. ISLAND, N.Z.
# 4        NORTHERN SUMATRA, INDONESIA
# 5         NEAR SOUTH COAST OF FRANCE
# 6                  WESTERN AUSTRALIA
# 7                     EASTERN TURKEY
# 8                      NORTHERN PERU
# 9        SOUTH ISLAND OF NEW ZEALAND
# 10          ISLAND OF HAWAII, HAWAII
# 11          AZORES ISLANDS, PORTUGAL
# 12     NORTHERN TERRITORY, AUSTRALIA
# 13   OFF EAST COAST OF HONSHU, JAPAN
# 14   OFF E. COAST OF N. ISLAND, N.Z.
# 15                   COQUIMBO, CHILE
# 16               STRAIT OF GIBRALTAR
# 17          FLORES REGION, INDONESIA
# 18          FLORES REGION, INDONESIA
# 19                 NORTHERN COLOMBIA

# %% [markdown]
# #### Count the number of tweets by a given Twitter account.
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here

# %% [markdown]
# #### Number of followers of a given twitter account
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the followers for any provided account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
# your code here

html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
languages_data = soup.find_all(class_ = "central-featured-lang")
languages_names = [l.strong.text for l in languages_data]
languages_related_articles = [l.bdi.text.replace("\xa0", " ") for l in languages_data]

languages_dict = {languages_names[i]:languages_related_articles[i] for i in range(len(languages_names))}

languages_dict
# Out:
# {'English': '6 383 000+',
#  '日本語': '1 292 000+',
#  'Русский': '1 756 000+',
#  'Deutsch': '2 617 000+',
#  'Español': '1 717 000+',
#  'Français': '2 362 000+',
#  '中文': '1 231 000+',
#  'Italiano': '1 718 000+',
#  'Polski': '1 490 000+',
#  'Português': '1 074 000+'}

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk.

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
# your code here
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
data = soup.find_all("h3")
database = [m.text for m in data]
database
# Out:
# ['Business and economy',
#  'Crime and justice',
#  'Defence',
#  'Education',
#  'Environment',
#  'Government',
#  'Government spending',
#  'Health',
#  'Mapping',
#  'Society',
#  'Towns and cities',
#  'Transport',
#  'Digital service performance',
#  'Government reference data']

# %% [markdown]
# #### Display the top 10 languages by number of native speakers stored in a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
# your code here
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
table = soup.find_all('table',{'class':'wikitable'})[0]
rows= table.find_all('tr', limit = 11)
rows=[row.text.strip().split('\n') for row in rows]
import pandas as pd
colnames=rows[0]
data=rows[1:]
languages=pd.DataFrame(data,columns=colnames)
languages
# Out:
#   Rank                               Language   Speakers(millions)    \
# 0    1                       Mandarin Chinese                  918
# 1    2                                Spanish                  480
# 2    3                                English                  379
# 3    4    Hindi (sanskritised Hindustani)[11]                  341
# 4    5                                Bengali                  300
# 5    6                             Portuguese                  221
# 6    7                                Russian                  154
# 7    8                               Japanese                  128
# 8    9                    Western Punjabi[12]                 92.7
# 9   10                                Marathi                 83.1
#
#   Percentageof world pop.(March 2019)[10]   Language family          Branch
# 0                                 11.922%      Sino-Tibetan         Sinitic
# 1                                  5.994%     Indo-European         Romance
# 2                                  4.922%     Indo-European        Germanic
# 3                                  4.429%     Indo-European      Indo-Aryan
# 4                                  4.000%     Indo-European      Indo-Aryan
# 5                                  2.870%     Indo-European         Romance
# 6                                  2.000%     Indo-European    Balto-Slavic
# 7                                  1.662%           Japonic        Japanese
# 8                                  1.204%     Indo-European      Indo-Aryan
# 9                                  1.079%     Indo-European      Indo-Aryan

# %% [markdown]
# ## Bonus
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here

# %% [markdown]
# #### Display IMDB's top 250 data (movie name, initial release, director name and stars) as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code here
import pandas as pd
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
soup.prettify()
table = soup.find_all('table',{'<td class>':'titleColumn'})[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16148/3103176769.py in <module>
#       4 soup = BeautifulSoup(html, "lxml")
#       5 soup.prettify()
# ----> 6 table = soup.find_all('table',{'<td class>':'titleColumn'})[0]
#
# IndexError: list index out of range

# %% [markdown]
# #### Display the movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
# your code here
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16148/956061569.py in <module>
#       3 html = requests.get(url).content
#       4 soup = BeautifulSoup(html, "lxml")
# ----> 5 df=pd.Dataframe(soup)
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = input('Enter the city: ')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code here

# %% [markdown]
# #### Find the book name, price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
# your code here
